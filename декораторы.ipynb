# %% [markdown]
# Пример 1.

# %%
# coding=UTF-8
class TestClass:

    def __init__(self):
        self.public_variable = "I'm public!"
        self.__private_variable = "I'm too shy to be public!"

    def get_public_variable(self):
        return self.public_variable

    def get_private_variable(self):
        return self.__private_variable

if __name__ == "__main__":
    test_class = TestClass()
    print(" ".join(["Public variable:", test_class.get_public_variable()]))
    print(" ".join(["Public variable:", test_class.public_variable]))

    print(" ".join(["Private variable:", test_class.get_private_variable()]))
    print(" ".join(["Private variable:", test_class._private_variable]))
# Out:
# Public variable: I'm public!
# Public variable: I'm public!
# Private variable: I'm too shy to be public!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-b54941b0f4fd> in <module>()
#      17
#      18     print(" ".join(["Private variable:", test_class.get_private_variable()]))
# ---> 19     print(" ".join(["Private variable:", test_class._private_variable]))
#
# AttributeError: 'TestClass' object has no attribute '_private_variable'

# %% [markdown]
# Пример 2.

# %%
class Student(UniversityMember):
    group = None
    passToUniversity = ''
    status = True

    def checkStatus(self):
        return self.status

    def dismiss(self):
        self.status = False
        self.pass_to_university = None

class Teacher(UniversityMember):
    cathedral = None
    passToUniversity = ''
    status = True

    def checkStatus(self):
        return self.status

    def dismiss(self):
        self.status = False
        self.pass_to_university = None

class Administrator(UniversityMember):
    passToUniversity = ''
    status = True

    def checkStatus(self):
        return self.status

    def dismiss(self):
        self.status = False
        self.pass_to_university = None

# %%
class UniversityMember:
    passToUniversity = ''
    status = True

    def checkStatus(self):
        return self.status

    def dismiss(self):
        self.status = False
        self.pass_to_university = None

class Student(UniversityMember):
    group = None

class Teacher(UniversityMember):
    cathedral = None

class Administrator(UniversityMember):
    pass

# %% [markdown]
# Пример 3.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # classmethod чтобы создать объект по году рождения,
    # "альтернативный" конструктор
    @classmethod
    def fromBirthYear(cls, name, year):
        return cls(name, date.today().year - year)

    # статический метод,чтобы проверить совершеннолетие
    @staticmethod
    def isAdult(age):
        return age > 18

person1 = Person('Петя', 21)
person2 = Person.fromBirthYear('Петя', 1996)

print person1.age
print person2.age

# print the result
print Person.isAdult(22)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8d0b29337c97> in <module>()
#      16
#      17 person1 = Person('Петя', 21)
# ---> 18 person2 = Person.fromBirthYear('Петя', 1996)
#      19
#      20 print(person1.age)
#
# <ipython-input-3-8d0b29337c97> in fromBirthYear(cls, name, year)
#       8     @classmethod
#       9     def fromBirthYear(cls, name, year):
# ---> 10         return cls(name, date.today().year - year)
#      11
#      12     # статический метод,чтобы проверить совершеннолетие
#
# NameError: name 'date' is not defined

# %% [markdown]
# Упражнение1.

# %%
def decorator(func):
  def wrapper(arg1):
    c=func(arg1)
    if c==0:
      print("Нету")
    elif c>10:
      print("Очень много")
    else:
      print(c)
  return wrapper

@decorator
def my_function(a):
 even = 0
 odd = 0
 for i in a:
    if i%2 == 0:
        even += 1
 return even

a=[1, 7, 5, 1]
my_function(a)
# Out:
# Нету

# %% [markdown]
# Упражнение 2.

# %%
#(1, 2) + (3, -1) = (2, 1)
def decorator(func):
  def wrapper(self, other):
    res=func(self, other)
    print("(",self.x,",",self.y,") + (", other.x,",", other.y, ") = (", res.x,",", res.y, ")")
    
  return wrapper


class Vector2D:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    @decorator
    def __add__(self, other):
        return Vector2D(self.x + other.x, self.y + other.y)

A=Vector2D(1, 2)
B=Vector2D(3, -1)
C=A+B
# Out:
# ( 1 , 2 ) + ( 3 , -1 ) = ( 4 , 1 )
